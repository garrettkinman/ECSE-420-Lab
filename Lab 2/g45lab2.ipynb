# %% [markdown]
# # Part B: Finite Element Music Synthesis

# %% [markdown]
# ## Importing the libraries

# %%
import os
nvvm_lib_path = !find / -iname 'libnvvm.so'
dev_lib_path = !find / -iname 'libdevice'
assert len(nvvm_lib_path)>0, "NVVM Missing"
assert len(dev_lib_path)>0, "Device Lib Missing"
os.environ['NUMBAPRO_NVVM'] = nvvm_lib_path[0]
os.environ['NUMBAPRO_LIBDEVICE'] = dev_lib_path[0]

# %%
import cv2
import matplotlib.pyplot as plt
import math
import numpy as np
import numba
from numba import cuda
# Out:
# /usr/local/lib/python3.6/dist-packages/numba/cuda/envvars.py:17: NumbaWarning:
# Environment variables with the 'NUMBAPRO' prefix are deprecated and consequently ignored, found use of NUMBAPRO_NVVM=/usr/local/cuda-10.1/nvvm/lib64/libnvvm.so.
#
# For more information about alternatives visit: ('http://numba.pydata.org/numba-doc/latest/cuda/overview.html', '#cudatoolkit-lookup')
#   warnings.warn(errors.NumbaWarning(msg))
# /usr/local/lib/python3.6/dist-packages/numba/cuda/envvars.py:17: NumbaWarning:
# Environment variables with the 'NUMBAPRO' prefix are deprecated and consequently ignored, found use of NUMBAPRO_LIBDEVICE=/usr/local/cuda-10.1/nvvm/libdevice.
#
# For more information about alternatives visit: ('http://numba.pydata.org/numba-doc/latest/cuda/overview.html', '#cudatoolkit-lookup')
#   warnings.warn(errors.NumbaWarning(msg))

# %% [markdown]
# ## Part 1: Implementing grid Sequentially

# %%
def implement_sequentially(N, iterations):
    u = np.zeros([N, N], dtype = float) # displacement of element
    
    u1 = u.copy() # displacement at previous time step
    u2 = u.copy() # displacement at previous previous time step
    
    #Constants
    n = 0.0002
    p = 0.5
    G = 0.75 # boundary gain

    u1[2][2] = 1 #initialize
    for iterator in range(iterations):
        for i in range(1, N-1):
            
            for j in range(1, N-1):
              # Interior element operation
                u[i][j] = (
                    (p * (u1[i-1][j] + u1[i+1][j] + u1[i][j-1] + u1[i][j+1] - 4*u1[i][j])) + 
                           (2 * u1[i][j]) - ((1 - n) * u2[i][j])
                           )
                u[i][j] = u[i][j]/(1+n)

        for iter2 in range(1, N-1):
            # Updating side elements
            u[0][iter2] = G * u[1][iter2] # right side
            u[N-1][iter2] = G * u[N-2][iter2] # left side
            u[iter2][0] = G * u[iter2][1] # top side
            u[iter2][N-1] = G * u[iter2][N-2] # bottom side

        # Updating corner elements
        u[0][0] = G * u[1][0] # top left
        u[N-1][0] = G * u[N-2][0] # top right
        u[0][N-1] = G * u[0][N-2] # bottom left
        u[N-1][N-1] = G * u[N-1][N-2] # bottom right

        #Re-assigning u
        u2 = u1.copy()
        u1 = u.copy()

        print("u[2, 2] at iteration {}: {}".format(iterator, u[2, 2]))

implement_sequentially(4, 4)
# Out:
# u[2, 2] at iteration 0: 0.0
# u[2, 2] at iteration 1: -0.49980001999999923
# u[2, 2] at iteration 2: 2.9982007234403314e-08
# u[2, 2] at iteration 3: 0.28102511495301846

# %% [markdown]
# ## Part 2: Single Thread Parallelization

# %%
# Constants

n = 0.0002
p = 0.5
G = 0.75

# Grid config
g_size = 4
grid = np.zeros((g_size, g_size)) # new grid
grid_1 = grid.copy()
grid_2 = grid.copy()
grid_1[2][2] = 1   # initialize

# Parameters
num_of_blocks = 978
numThreads_perBlock = 1000
iterations_T = 50


@cuda.jit
def parallel_interior(grid, grid_1, grid_2, n, p):
  
  idx = cuda.threadIdx.x + cuda.blockIdx.x * cuda.blockDim.x

  if idx < 16:
    j = idx // 4
    i = idx % 4
    
    # Interior node operation
    if i not in [0, 3] and j not in [0, 3]:
      
      grid[i][j] = ((p * (grid_1[i-1][j] + grid_1[i+1][j] + grid_1[i][j-1] + grid_1[i][j+1] - 4 * grid_1[i][j])) + 
                    (2 * grid_1[i][j]) - ((1 - n) * grid_2[i][j]))
      grid[i][j] = grid[i][j]/(1 + n)

@cuda.jit
def parallel_sides(grid, G):
  
  idx = cuda.threadIdx.x + cuda.blockIdx.x * cuda.blockDim.x

  if idx < 16:
    j = idx // 4
    i = idx % 4
    
    # Updating sides
    if i == 0 and j in [1, 2]:
      grid[i][j] = G * grid[i + 1][j] # left side
    elif i == 3 and j in [1, 2]:
      grid[i][j] = G * grid[i - 1][j]  # right side
    elif j == 0 and i in [1, 2]:
      grid[i][j] = G * grid[i][j + 1] # top side
    elif j == 3 and i in [1, 2]:
      grid[i][j] = G * grid[i][j - 1] # bottom side

@cuda.jit
def parallel_corners(grid, G):
  idx = cuda.threadIdx.x + cuda.blockIdx.x * cuda.blockDim.x

  if idx < 16:
    j = idx // 4
    i = idx % 4

    # Updating corners
    if i == 0 and j == 0:
      grid[i][j] = G * grid[i + 1][j] # top left corner
    elif i == 0 and j == 3:
      grid[i][j] = G * grid[i][j - 1] # bottom left corner
    elif i == 3 and j == 0:
      grid[i][j] = G * grid[i][j + 1] # top right corner
    elif i == 3 and j == 3:
      grid[i][j] = G * grid[i][j - 1] # bottom right corner


# executing parallelization
for iteration in range(iterations_T):
  parallel_interior[num_of_blocks, numThreads_perBlock](grid, grid_1, grid_2, n, p)
  parallel_sides[num_of_blocks, numThreads_perBlock](grid, G)
  parallel_corners[num_of_blocks, numThreads_perBlock](grid, G)
  
  print("u[2, 2] at iteration {}: {}".format(iteration, grid[2][2]))

  grid_2 = grid_1.copy()
  grid_1 = grid.copy()
# Out:
# u[2, 2] at iteration 0: 0.0
# u[2, 2] at iteration 1: -0.49980001999999923
# u[2, 2] at iteration 2: 2.9982007234403314e-08
# u[2, 2] at iteration 3: 0.2810251149530184
# u[2, 2] at iteration 4: 0.04682818495502672
# u[2, 2] at iteration 5: -0.08778516995465212
# u[2, 2] at iteration 6: -0.32181476130245723
# u[2, 2] at iteration 7: -0.74136664956306
# u[2, 2] at iteration 8: -0.38839948920730266
# u[2, 2] at iteration 9: 0.6652254330040654
# u[2, 2] at iteration 10: 0.7787261426358246
# u[2, 2] at iteration 11: -0.22371278398803726
# u[2, 2] at iteration 12: -0.5139857688941788
# u[2, 2] at iteration 13: 0.3315687356910853
# u[2, 2] at iteration 14: 0.7216416509417185
# u[2, 2] at iteration 15: 0.16843621887136329
# u[2, 2] at iteration 16: -0.28548607266696807
# u[2, 2] at iteration 17: -0.4078320015272444
# u[2, 2] at iteration 18: -0.563128497465155
# u[2, 2] at iteration 19: -0.2835166141928366
# u[2, 2] at iteration 20: 0.4472320260386376
# u[2, 2] at iteration 21: 0.39596970515004054
# u[2, 2] at iteration 22: -0.496526695683186
# u[2, 2] at iteration 23: -0.5256373939774961
# u[2, 2] at iteration 24: 0.5760366497416338
# u[2, 2] at iteration 25: 0.9926034468428319
# u[2, 2] at iteration 26: 0.1908710314349021
# u[2, 2] at iteration 27: -0.4025014078396819
# u[2, 2] at iteration 28: -0.27847620339368123
# u[2, 2] at iteration 29: -0.1845074875605142
# u[2, 2] at iteration 30: -0.11426122887022694
# u[2, 2] at iteration 31: 0.18264642990383687
# u[2, 2] at iteration 32: -0.006543707448174733
# u[2, 2] at iteration 33: -0.7084566412480809
# u[2, 2] at iteration 34: -0.5236507316698267
# u[2, 2] at iteration 35: 0.6606126905303338
# u[2, 2] at iteration 36: 1.011229967369607
# u[2, 2] at iteration 37: 0.06969105659603876
# u[2, 2] at iteration 38: -0.47278567809030636
# u[2, 2] at iteration 39: -0.007734276427380817
# u[2, 2] at iteration 40: 0.29785640628725146
# u[2, 2] at iteration 41: 0.08372459141656625
# u[2, 2] at iteration 42: -0.05317669912526922
# u[2, 2] at iteration 43: -0.29017494547559003
# u[2, 2] at iteration 44: -0.7503066244101299
# u[2, 2] at iteration 45: -0.4712290728134359
# u[2, 2] at iteration 46: 0.5823734455406359
# u[2, 2] at iteration 47: 0.7847448542273362
# u[2, 2] at iteration 48: -0.18063500872074204
# u[2, 2] at iteration 49: -0.5312129608171092

# %% [markdown]
# ## Part 3 - Multiple Block Parallelization

# %%
# Constants
G = 0.75
n = 0.0002
p = 0.5
g_size = 512

# Grid config
grid = np.zeros((g_size, g_size))
grid_1 = grid.copy()
grid_2 = grid.copy()
grid_1[g_size // 2][g_size // 2] = 1   # initialize

# Parameters
iterations_T = 50
num_of_blocks = 978
numThreads_perBlock = 1000
elements_per_thread = 16

@cuda.jit
def multi_interior(grid, grid_1, grid_2, n, p, g_size, elements_in_thread, needed_threads):
  
  idx = cuda.threadIdx.x + cuda.blockIdx.x * cuda.blockDim.x

  if idx < needed_threads:
    
    for iter in range(elements_in_thread):
    
      this_Idx = idx * elements_in_thread + iter
      # Keeping track of previous grids
      if this_Idx < g_size * g_size:
        j = this_Idx // g_size
        i = this_Idx % g_size
        if i != 0 and j != 0 and i != g_size - 1 and j != g_size - 1:
          # Interior node operation
          grid[i][j] = (
              (p * (grid_1[i-1][j] + grid_1[i+1][j] + grid_1[i][j-1] + grid_1[i][j+1] - 4 * grid_1[i][j])) + 
                        (2 * grid_1[i][j]) - ((1 - n) * grid_2[i][j]))
          grid[i][j] = grid[i][j]/(1 + n)

@cuda.jit
def multi_sides(grid, G, g_size, elements_in_thread, needed_threads):
  
  idx = cuda.threadIdx.x + cuda.blockIdx.x * cuda.blockDim.x

  if idx < needed_threads:
    
    for iter in range(elements_in_thread):
      # Keeping track of previous grids
      this_Idx = idx * elements_in_thread + iter

      if this_Idx < g_size * g_size:
        j = this_Idx // g_size
        i = this_Idx % g_size

        # Updating sides
        if i == 0 and j in [1, 2]:
          grid[i][j] = G * grid[i + 1][j] # left side
        elif i == 3 and j in [1, 2]:
          grid[i][j] = G * grid[i - 1][j] # right side
        elif j == 0 and i in [1, 2]:
          grid[i][j] = G * grid[i][j + 1] # top side
        elif j == 3 and i in [1, 2]:
          grid[i][j] = G * grid[i][j - 1] # bottom side

@cuda.jit
def multi_corners(grid, G, g_size, elements_in_thread, needed_threads):
  idx = cuda.threadIdx.x + cuda.blockIdx.x * cuda.blockDim.x

  if idx < needed_threads:

    for iter in range(elements_in_thread):
      # updating on adjacent nodes isn't a problem because we're using the history grids only
      this_Idx = idx * elements_in_thread + iter

      if this_Idx < g_size * g_size:
        j = this_Idx // g_size
        i = this_Idx % g_size
        # Updating corners
        if i == 0 and j == 0:
          grid[i][j] = G * grid[i + 1][j] # top left corner
        elif i == 0 and j == 3:
          grid[i][j] = G * grid[i][j - 1] # bottom left corner
        elif i == 3 and j == 0:
          grid[i][j] = G * grid[i][j + 1] # top right corner
        elif i == 3 and j == 3:
          grid[i][j] = G * grid[i][j - 1] # bottom right corner


# executing multi parallelization
needed_threads = math.ceil((g_size * g_size) / elements_per_thread)
for iter in range(iterations_T):
  multi_interior[num_of_blocks, numThreads_perBlock](grid, grid_1, grid_2, n, p, g_size, elements_per_thread, needed_threads)
  multi_sides[num_of_blocks, numThreads_perBlock](grid, G, g_size, elements_per_thread, needed_threads)
  multi_corners[num_of_blocks, numThreads_perBlock](grid, G, g_size, elements_per_thread, needed_threads)
  
  print("Iteration {}: {}".format(iter, grid[g_size // 2][g_size // 2]))

  grid_2 = grid_1.copy()
  grid_1 = grid.copy()
# Out:
# Iteration 0: 0.0
# Iteration 1: 3.998400479824981e-08
# Iteration 2: 0.0
# Iteration 3: 0.24980013992803154
# Iteration 4: 0.0
# Iteration 5: 8.9892080370116e-08
# Iteration 6: 0.0
# Iteration 7: 0.14040029222121936
# Iteration 8: 0.0
# Iteration 9: 1.403440891682952e-07
# Iteration 10: 0.0
# Iteration 11: 0.09742231969133452
# Iteration 12: 0.0
# Iteration 13: 1.9087120709162718e-07
# Iteration 14: 0.0
# Iteration 15: 0.0745294056393437
# Iteration 16: 0.0
# Iteration 17: 2.413783011458448e-07
# Iteration 18: 0.0
# Iteration 19: 0.060320634512427584
# Iteration 20: 0.0
# Iteration 21: 2.918343471751079e-07
# Iteration 22: 0.0
# Iteration 23: 0.050645649253699805
# Iteration 24: 0.0
# Iteration 25: 3.4222637009984303e-07
# Iteration 26: 0.0
# Iteration 27: 0.0436341257299501
# Iteration 28: 0.0
# Iteration 29: 3.925480441346873e-07
# Iteration 30: 0.0
# Iteration 31: 0.03831973287361857
# Iteration 32: 0.0
# Iteration 33: 4.4279595196121775e-07
# Iteration 34: 0.0
# Iteration 35: 0.03415301791490642
# Iteration 36: 0.0
# Iteration 37: 4.929681108493421e-07
# Iteration 38: 0.0
# Iteration 39: 0.030798546140529577
# Iteration 40: 0.0
# Iteration 41: 5.430633118003722e-07
# Iteration 42: 0.0
# Iteration 43: 0.028039967254005736
# Iteration 44: 0.0
# Iteration 45: 5.930807933462375e-07
# Iteration 46: 0.0
# Iteration 47: 0.02573148721548688
# Iteration 48: 0.0
# Iteration 49: 6.43020065892496e-07

# %% [markdown]
# ## Comparing Results
# Checking if results in Part 3 are the same for Part 1 and 2

# %%
# Constant
n = 0.0002
p = 0.5
G = 0.75

# Grid config
g_size = 4
grid = np.zeros((g_size, g_size))
grid_1 = grid.copy()
grid_2 = grid.copy()
grid_1[g_size // 2][g_size // 2] = 1   # initialize

# variable parameters
num_of_blocks = 978
numThreads_perBlock = 1000
elements_per_thread = 16
iterations_T = 50

needed_threads = math.ceil((g_size * g_size) / elements_per_thread)

# executing multi paralellization
for iter in range(iterations_T):
  multi_interior[num_of_blocks, numThreads_perBlock](grid, grid_1, grid_2, n, p, g_size, elements_per_thread, needed_threads)
  multi_sides[num_of_blocks, numThreads_perBlock](grid, G, g_size, elements_per_thread, needed_threads)
  multi_corners[num_of_blocks, numThreads_perBlock](grid, G, g_size, elements_per_thread, needed_threads)
  
  print("Iteration {}: {}".format(iter, grid[g_size // 2][g_size // 2]))

  grid_2 = grid_1.copy()
  grid_1 = grid.copy()
# Out:
# Iteration 0: 0.0
# Iteration 1: -0.49980001999999923
# Iteration 2: 2.9982007234403314e-08
# Iteration 3: 0.2810251149530184
# Iteration 4: 0.04682818495502672
# Iteration 5: -0.08778516995465212
# Iteration 6: -0.32181476130245723
# Iteration 7: -0.74136664956306
# Iteration 8: -0.38839948920730266
# Iteration 9: 0.6652254330040654
# Iteration 10: 0.7787261426358246
# Iteration 11: -0.22371278398803726
# Iteration 12: -0.5139857688941788
# Iteration 13: 0.3315687356910853
# Iteration 14: 0.7216416509417185
# Iteration 15: 0.16843621887136329
# Iteration 16: -0.28548607266696807
# Iteration 17: -0.4078320015272444
# Iteration 18: -0.563128497465155
# Iteration 19: -0.2835166141928366
# Iteration 20: 0.4472320260386376
# Iteration 21: 0.39596970515004054
# Iteration 22: -0.496526695683186
# Iteration 23: -0.5256373939774961
# Iteration 24: 0.5760366497416338
# Iteration 25: 0.9926034468428319
# Iteration 26: 0.1908710314349021
# Iteration 27: -0.4025014078396819
# Iteration 28: -0.27847620339368123
# Iteration 29: -0.1845074875605142
# Iteration 30: -0.11426122887022694
# Iteration 31: 0.18264642990383687
# Iteration 32: -0.006543707448174733
# Iteration 33: -0.7084566412480809
# Iteration 34: -0.5236507316698267
# Iteration 35: 0.6606126905303338
# Iteration 36: 1.011229967369607
# Iteration 37: 0.06969105659603876
# Iteration 38: -0.47278567809030636
# Iteration 39: -0.007734276427380817
# Iteration 40: 0.29785640628725146
# Iteration 41: 0.08372459141656625
# Iteration 42: -0.05317669912526922
# Iteration 43: -0.29017494547559003
# Iteration 44: -0.7503066244101299
# Iteration 45: -0.4712290728134359
# Iteration 46: 0.5823734455406359
# Iteration 47: 0.7847448542273362
# Iteration 48: -0.18063500872074204
# Iteration 49: -0.5312129608171092

# %% [markdown]
# Evidently from the above results of Part 3, we can confirm that they are the same as those of Part 1 and 2. Hence, the multi paralellization was done correctly.

# %% [markdown]
# ## Speed-up Data

# %%
import time

# Constant
n = 0.0002
p = 0.5
G = 0.75

# grid creation
g_size = 512
grid = np.zeros((g_size, g_size))
grid_1 = grid.copy()
grid_2 = grid.copy()
grid_1[g_size // 2][g_size // 2] = 1   # initialize

iterations_T = 500

for num_of_blocks in [1, 4, 8, 32, 128, 512, 2048]:
  
  for numThreads_perBlock in [1, 4, 16, 64, 256, 1024]:
    
    for elements_per_thread in [1, 4, 16, 64, 256]:
      start = time.time()
      needed_threads = math.ceil((g_size * g_size) / elements_per_thread)

      # executing multi paralellization
      for iter in range(iterations_T):
        drum_interiorMult[num_of_blocks, numThreads_perBlock](grid, grid_1, grid_2, n, p, g_size, elements_per_thread, needed_threads)
        drum_edgesMult[num_of_blocks, numThreads_perBlock](grid, G, g_size, elements_per_thread, needed_threads)
        drum_cornersMult[num_of_blocks, numThreads_perBlock](grid, G, g_size, elements_per_thread, needed_threads)

        grid_2 = grid_1.copy()
        grid_1 = grid.copy()
      
      print("Runtime for {} blocks, {} threads, {} elements: {}".format(num_of_blocks, numThreads_perBlock, elements_per_thread, time.time() - start))
# Out:
# Runtime for 1 blocks, 1 threads, 1 elements: 4.560439825057983
# Runtime for 1 blocks, 1 threads, 4 elements: 4.587965250015259
# Runtime for 1 blocks, 1 threads, 16 elements: 4.549238920211792
# Runtime for 1 blocks, 1 threads, 64 elements: 4.614914178848267
# Runtime for 1 blocks, 1 threads, 256 elements: 4.8032026290893555
# Runtime for 1 blocks, 4 threads, 1 elements: 4.589372396469116
# Runtime for 1 blocks, 4 threads, 4 elements: 4.562153577804565
# Runtime for 1 blocks, 4 threads, 16 elements: 4.586965084075928
# Runtime for 1 blocks, 4 threads, 64 elements: 4.559335231781006
# Runtime for 1 blocks, 4 threads, 256 elements: 5.088643312454224
# Runtime for 1 blocks, 16 threads, 1 elements: 4.554551124572754
# Runtime for 1 blocks, 16 threads, 4 elements: 4.570990800857544
# Runtime for 1 blocks, 16 threads, 16 elements: 4.593151807785034
# Runtime for 1 blocks, 16 threads, 64 elements: 4.652085781097412
# Runtime for 1 blocks, 16 threads, 256 elements: 5.200481414794922
# Runtime for 1 blocks, 64 threads, 1 elements: 4.534957647323608
# Runtime for 1 blocks, 64 threads, 4 elements: 4.54125189781189
# Runtime for 1 blocks, 64 threads, 16 elements: 4.590123176574707
# Runtime for 1 blocks, 64 threads, 64 elements: 4.607059717178345
# Runtime for 1 blocks, 64 threads, 256 elements: 5.189187526702881
# Runtime for 1 blocks, 256 threads, 1 elements: 4.570799827575684
# Runtime for 1 blocks, 256 threads, 4 elements: 4.545595407485962
# Runtime for 1 blocks, 256 threads, 16 elements: 4.591046094894409
# Runtime for 1 blocks, 256 threads, 64 elements: 4.738240003585815
# Runtime for 1 blocks, 256 threads, 256 elements: 5.406729459762573
# Runtime for 1 blocks, 1024 threads, 1 elements: 4.549997329711914
# Runtime for 1 blocks, 1024 threads, 4 elements: 4.593828916549683
# Runtime for 1 blocks, 1024 threads, 16 elements: 4.695796012878418
# Runtime for 1 blocks, 1024 threads, 64 elements: 5.38918399810791
# Runtime for 1 blocks, 1024 threads, 256 elements: 5.898076295852661
# Runtime for 4 blocks, 1 threads, 1 elements: 4.513940095901489
# Runtime for 4 blocks, 1 threads, 4 elements: 4.572561025619507
# Runtime for 4 blocks, 1 threads, 16 elements: 4.580537557601929
# Runtime for 4 blocks, 1 threads, 64 elements: 4.558675289154053
# Runtime for 4 blocks, 1 threads, 256 elements: 5.15051531791687
# Runtime for 4 blocks, 4 threads, 1 elements: 4.515822887420654
# Runtime for 4 blocks, 4 threads, 4 elements: 4.5661780834198
# Runtime for 4 blocks, 4 threads, 16 elements: 4.549791097640991
# Runtime for 4 blocks, 4 threads, 64 elements: 4.613649129867554
# Runtime for 4 blocks, 4 threads, 256 elements: 5.125483989715576
# Runtime for 4 blocks, 16 threads, 1 elements: 4.573285102844238
# Runtime for 4 blocks, 16 threads, 4 elements: 4.52813720703125
# Runtime for 4 blocks, 16 threads, 16 elements: 4.525154113769531
# Runtime for 4 blocks, 16 threads, 64 elements: 4.639678955078125
# Runtime for 4 blocks, 16 threads, 256 elements: 5.208920478820801
# Runtime for 4 blocks, 64 threads, 1 elements: 4.549508571624756
# Runtime for 4 blocks, 64 threads, 4 elements: 4.532254934310913
# Runtime for 4 blocks, 64 threads, 16 elements: 4.591196060180664
# Runtime for 4 blocks, 64 threads, 64 elements: 4.680267810821533
# Runtime for 4 blocks, 64 threads, 256 elements: 5.232909440994263
# Runtime for 4 blocks, 256 threads, 1 elements: 4.6023781299591064
# Runtime for 4 blocks, 256 threads, 4 elements: 4.574306011199951
# Runtime for 4 blocks, 256 threads, 16 elements: 4.589341402053833
# Runtime for 4 blocks, 256 threads, 64 elements: 4.764838933944702
# Runtime for 4 blocks, 256 threads, 256 elements: 5.449343204498291
# Runtime for 4 blocks, 1024 threads, 1 elements: 4.542787075042725
# Runtime for 4 blocks, 1024 threads, 4 elements: 4.571559190750122
# Runtime for 4 blocks, 1024 threads, 16 elements: 4.728010416030884
# Runtime for 4 blocks, 1024 threads, 64 elements: 5.354471206665039
# Runtime for 4 blocks, 1024 threads, 256 elements: 5.900905132293701
# Runtime for 8 blocks, 1 threads, 1 elements: 4.498844861984253
# Runtime for 8 blocks, 1 threads, 4 elements: 4.521311521530151
# Runtime for 8 blocks, 1 threads, 16 elements: 4.554673433303833
# Runtime for 8 blocks, 1 threads, 64 elements: 4.555074691772461
# Runtime for 8 blocks, 1 threads, 256 elements: 5.128860235214233
# Runtime for 8 blocks, 4 threads, 1 elements: 4.5431694984436035
# Runtime for 8 blocks, 4 threads, 4 elements: 4.586021184921265
# Runtime for 8 blocks, 4 threads, 16 elements: 4.606082916259766
# Runtime for 8 blocks, 4 threads, 64 elements: 4.630747079849243
# Runtime for 8 blocks, 4 threads, 256 elements: 5.229349613189697
# Runtime for 8 blocks, 16 threads, 1 elements: 4.612708330154419
# Runtime for 8 blocks, 16 threads, 4 elements: 4.608546495437622
# Runtime for 8 blocks, 16 threads, 16 elements: 4.52019190788269
# Runtime for 8 blocks, 16 threads, 64 elements: 4.649983644485474
# Runtime for 8 blocks, 16 threads, 256 elements: 5.234639883041382
# Runtime for 8 blocks, 64 threads, 1 elements: 4.556924819946289
# Runtime for 8 blocks, 64 threads, 4 elements: 4.579495429992676
# Runtime for 8 blocks, 64 threads, 16 elements: 4.539346933364868
# Runtime for 8 blocks, 64 threads, 64 elements: 4.656954288482666
# Runtime for 8 blocks, 64 threads, 256 elements: 5.224124431610107
# Runtime for 8 blocks, 256 threads, 1 elements: 4.5809783935546875
# Runtime for 8 blocks, 256 threads, 4 elements: 4.547854661941528
# Runtime for 8 blocks, 256 threads, 16 elements: 4.552476644515991
# Runtime for 8 blocks, 256 threads, 64 elements: 4.754562139511108
# Runtime for 8 blocks, 256 threads, 256 elements: 5.403664588928223
# Runtime for 8 blocks, 1024 threads, 1 elements: 4.597555637359619
# Runtime for 8 blocks, 1024 threads, 4 elements: 4.572468280792236
# Runtime for 8 blocks, 1024 threads, 16 elements: 4.733278751373291
# Runtime for 8 blocks, 1024 threads, 64 elements: 5.38276219367981
# Runtime for 8 blocks, 1024 threads, 256 elements: 5.941246032714844
# Runtime for 32 blocks, 1 threads, 1 elements: 4.489577293395996
# Runtime for 32 blocks, 1 threads, 4 elements: 4.506404638290405
# Runtime for 32 blocks, 1 threads, 16 elements: 4.544771909713745
# Runtime for 32 blocks, 1 threads, 64 elements: 4.6286492347717285
# Runtime for 32 blocks, 1 threads, 256 elements: 5.110386371612549
# Runtime for 32 blocks, 4 threads, 1 elements: 4.6013946533203125
# Runtime for 32 blocks, 4 threads, 4 elements: 4.595094680786133
# Runtime for 32 blocks, 4 threads, 16 elements: 4.597916603088379
# Runtime for 32 blocks, 4 threads, 64 elements: 4.843444347381592
# Runtime for 32 blocks, 4 threads, 256 elements: 5.2666778564453125
# Runtime for 32 blocks, 16 threads, 1 elements: 4.699625015258789
# Runtime for 32 blocks, 16 threads, 4 elements: 4.631944179534912
# Runtime for 32 blocks, 16 threads, 16 elements: 4.6780126094818115
# Runtime for 32 blocks, 16 threads, 64 elements: 4.701147556304932
# Runtime for 32 blocks, 16 threads, 256 elements: 5.33007025718689
# Runtime for 32 blocks, 64 threads, 1 elements: 4.673379421234131
# Runtime for 32 blocks, 64 threads, 4 elements: 4.675616264343262
# Runtime for 32 blocks, 64 threads, 16 elements: 4.654308319091797
# Runtime for 32 blocks, 64 threads, 64 elements: 4.762417316436768
# Runtime for 32 blocks, 64 threads, 256 elements: 5.26994776725769
# Runtime for 32 blocks, 256 threads, 1 elements: 4.606079578399658
# Runtime for 32 blocks, 256 threads, 4 elements: 4.552915573120117
# Runtime for 32 blocks, 256 threads, 16 elements: 4.621844053268433
# Runtime for 32 blocks, 256 threads, 64 elements: 4.785276174545288
# Runtime for 32 blocks, 256 threads, 256 elements: 5.583568334579468
# Runtime for 32 blocks, 1024 threads, 1 elements: 4.665521144866943
# Runtime for 32 blocks, 1024 threads, 4 elements: 4.601422309875488
# Runtime for 32 blocks, 1024 threads, 16 elements: 4.81032133102417
# Runtime for 32 blocks, 1024 threads, 64 elements: 5.434155464172363
# Runtime for 32 blocks, 1024 threads, 256 elements: 5.9599854946136475
# Runtime for 128 blocks, 1 threads, 1 elements: 4.501126289367676
# Runtime for 128 blocks, 1 threads, 4 elements: 4.598480463027954
# Runtime for 128 blocks, 1 threads, 16 elements: 4.613921880722046
# Runtime for 128 blocks, 1 threads, 64 elements: 4.7503767013549805
# Runtime for 128 blocks, 1 threads, 256 elements: 5.321686267852783
# Runtime for 128 blocks, 4 threads, 1 elements: 4.569911479949951
# Runtime for 128 blocks, 4 threads, 4 elements: 4.642352819442749
# Runtime for 128 blocks, 4 threads, 16 elements: 4.554674863815308
# Runtime for 128 blocks, 4 threads, 64 elements: 4.71302604675293
# Runtime for 128 blocks, 4 threads, 256 elements: 5.376117706298828
# Runtime for 128 blocks, 16 threads, 1 elements: 4.599178075790405
# Runtime for 128 blocks, 16 threads, 4 elements: 4.600991725921631
# Runtime for 128 blocks, 16 threads, 16 elements: 4.5954530239105225
# Runtime for 128 blocks, 16 threads, 64 elements: 4.73821759223938
# Runtime for 128 blocks, 16 threads, 256 elements: 5.408807039260864
# Runtime for 128 blocks, 64 threads, 1 elements: 4.651442527770996
# Runtime for 128 blocks, 64 threads, 4 elements: 4.609418153762817
# Runtime for 128 blocks, 64 threads, 16 elements: 4.601003646850586
# Runtime for 128 blocks, 64 threads, 64 elements: 4.708742380142212
# Runtime for 128 blocks, 64 threads, 256 elements: 5.3916380405426025
# Runtime for 128 blocks, 256 threads, 1 elements: 4.563254356384277
# Runtime for 128 blocks, 256 threads, 4 elements: 4.567329168319702
# Runtime for 128 blocks, 256 threads, 16 elements: 4.639125823974609
# Runtime for 128 blocks, 256 threads, 64 elements: 4.983964204788208
# Runtime for 128 blocks, 256 threads, 256 elements: 5.573476791381836
# Runtime for 128 blocks, 1024 threads, 1 elements: 4.585846662521362
# Runtime for 128 blocks, 1024 threads, 4 elements: 4.682719945907593
# Runtime for 128 blocks, 1024 threads, 16 elements: 4.784943103790283
# Runtime for 128 blocks, 1024 threads, 64 elements: 5.4626524448394775
# Runtime for 128 blocks, 1024 threads, 256 elements: 5.94586443901062
# Runtime for 512 blocks, 1 threads, 1 elements: 4.568904876708984
# Runtime for 512 blocks, 1 threads, 4 elements: 4.572588682174683
# Runtime for 512 blocks, 1 threads, 16 elements: 4.615145444869995
# Runtime for 512 blocks, 1 threads, 64 elements: 4.8689539432525635
# Runtime for 512 blocks, 1 threads, 256 elements: 5.459832429885864
# Runtime for 512 blocks, 4 threads, 1 elements: 4.565476894378662
# Runtime for 512 blocks, 4 threads, 4 elements: 4.536334991455078
# Runtime for 512 blocks, 4 threads, 16 elements: 4.6449501514434814
# Runtime for 512 blocks, 4 threads, 64 elements: 4.903539419174194
# Runtime for 512 blocks, 4 threads, 256 elements: 5.441539525985718
# Runtime for 512 blocks, 16 threads, 1 elements: 4.596192836761475
# Runtime for 512 blocks, 16 threads, 4 elements: 4.546013116836548
# Runtime for 512 blocks, 16 threads, 16 elements: 4.58896803855896
# Runtime for 512 blocks, 16 threads, 64 elements: 4.76633358001709
# Runtime for 512 blocks, 16 threads, 256 elements: 5.249345302581787
# Runtime for 512 blocks, 64 threads, 1 elements: 4.656523704528809
# Runtime for 512 blocks, 64 threads, 4 elements: 4.640040159225464
# Runtime for 512 blocks, 64 threads, 16 elements: 4.706653118133545
# Runtime for 512 blocks, 64 threads, 64 elements: 4.6697118282318115
# Runtime for 512 blocks, 64 threads, 256 elements: 5.342068910598755
# Runtime for 512 blocks, 256 threads, 1 elements: 4.581792593002319
# Runtime for 512 blocks, 256 threads, 4 elements: 4.610353231430054
# Runtime for 512 blocks, 256 threads, 16 elements: 4.6306281089782715
# Runtime for 512 blocks, 256 threads, 64 elements: 4.959491014480591
# Runtime for 512 blocks, 256 threads, 256 elements: 5.471472501754761
# Runtime for 512 blocks, 1024 threads, 1 elements: 4.574478387832642
# Runtime for 512 blocks, 1024 threads, 4 elements: 4.628286600112915
# Runtime for 512 blocks, 1024 threads, 16 elements: 4.761047601699829
# Runtime for 512 blocks, 1024 threads, 64 elements: 5.392775058746338
# Runtime for 512 blocks, 1024 threads, 256 elements: 5.9390294551849365
# Runtime for 2048 blocks, 1 threads, 1 elements: 4.565419435501099
# Runtime for 2048 blocks, 1 threads, 4 elements: 4.608593702316284
# Runtime for 2048 blocks, 1 threads, 16 elements: 4.938472270965576
# Runtime for 2048 blocks, 1 threads, 64 elements: 5.370513439178467
# Runtime for 2048 blocks, 1 threads, 256 elements: 5.760825872421265
# Runtime for 2048 blocks, 4 threads, 1 elements: 4.48514461517334
# Runtime for 2048 blocks, 4 threads, 4 elements: 4.581906795501709
# Runtime for 2048 blocks, 4 threads, 16 elements: 4.902095556259155
# Runtime for 2048 blocks, 4 threads, 64 elements: 5.33236837387085
# Runtime for 2048 blocks, 4 threads, 256 elements: 5.431630373001099
# Runtime for 2048 blocks, 16 threads, 1 elements: 4.545720100402832
# Runtime for 2048 blocks, 16 threads, 4 elements: 4.583648204803467
# Runtime for 2048 blocks, 16 threads, 16 elements: 4.679489612579346
# Runtime for 2048 blocks, 16 threads, 64 elements: 4.677796363830566
# Runtime for 2048 blocks, 16 threads, 256 elements: 5.257621765136719
# Runtime for 2048 blocks, 64 threads, 1 elements: 4.5438172817230225
# Runtime for 2048 blocks, 64 threads, 4 elements: 4.626545190811157
# Runtime for 2048 blocks, 64 threads, 16 elements: 4.760718822479248
# Runtime for 2048 blocks, 64 threads, 64 elements: 4.727172136306763
# Runtime for 2048 blocks, 64 threads, 256 elements: 5.362706422805786
# Runtime for 2048 blocks, 256 threads, 1 elements: 4.574032783508301
# Runtime for 2048 blocks, 256 threads, 4 elements: 4.587549686431885
# Runtime for 2048 blocks, 256 threads, 16 elements: 4.631303787231445
# Runtime for 2048 blocks, 256 threads, 64 elements: 4.977613925933838
# Runtime for 2048 blocks, 256 threads, 256 elements: 5.461580991744995
# Runtime for 2048 blocks, 1024 threads, 1 elements: 4.569894790649414
# Runtime for 2048 blocks, 1024 threads, 4 elements: 4.604937791824341
# Runtime for 2048 blocks, 1024 threads, 16 elements: 4.763804912567139
# Runtime for 2048 blocks, 1024 threads, 64 elements: 5.336099863052368
# Runtime for 2048 blocks, 1024 threads, 256 elements: 5.901544570922852
